# %%
# copy a list 
people: list[str] = ['Mario','Elon','Trump']

# %%
copy_people:list[str] = people.copy()

# %%
print(people)
# Out:
# ['Mario', 'Elon', 'Trump']

# %%
print(copy_people)
# Out:
# ['Mario', 'Elon', 'Trump']

# %%
#remove Trump
copy_people.remove('Trump')
print(people)
print(copy_people)
# Out:
# ['Mario', 'Elon', 'Trump']
# ['Mario', 'Elon']

# %%
people.append('Elon')
print(people)
print(people.count('Elon'))
# Out:
# ['Mario', 'Elon', 'Trump', 'Elon']
# 2

# %%
people2 = ['Modi','Ambani']

# %%
print(people.extend(people2))
# Out:
# None

# %%
people
# Out:
# ['Mario', 'Elon', 'Trump', 'Elon', 'Modi', 'Ambani']

# %%
# get the index
people.index('Trump')
# Out:
# 2

# %%
# insert element at a specific index
people.insert(1,'Adani')

# %%
people
# Out:
# ['Mario', 'Adani', 'Elon', 'Trump', 'Elon', 'Modi', 'Ambani']
